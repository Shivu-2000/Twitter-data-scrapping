# %% [markdown]
# # Music Tweets

# %%
#pip install snscrape
#Music

# %%
import pandas as pd
import snscrape.modules.twitter as sn

# %%
em=sn.TwitterUserScraper("iamcardib")

# %%
li=[]
for i,tweet in enumerate(em.get_items()):
    if i>100:
        break
    li.append([tweet.rawContent,tweet.date,tweet.likeCount,tweet.retweetCount,tweet.replyCount,"Music"])

# %%
df=pd.DataFrame(li,columns=['Tweet','Date','Like','Retweet','Comment','Output'])
df.to_csv('music.csv')

# %%
file=pd.read_csv('music.csv')
file
# Out:
#      Unnamed: 0                                              Tweet  \
# 0             0                  A mermaid https://t.co/djEypjcG27
# 1             1                                    Love this video
# 2             2  Yea cause you came to the club giving out your...
# 3             3      Motivating these hoes https://t.co/iLhmllIu3f
# 4             4  Giving yall bitches the best sex advice for va...
# ..          ...                                                ...
# 96           96                           OMMMGGG IN LIVING !!!!!!
# 97           97           MY TREES🎄🌲🎁❤️🧑‍🎄 https://t.co/ZqT95qPXkS
# 98           98                               I just don’t love it
# 99           99  HERE some scraps since yall STARVING 😫😂😂😫😂😫😫 h...
# 100         100  I just feel like these are things that people ...
#
#                           Date    Like  Retweet  Comment Output
# 0    2023-02-12 17:50:30+00:00    1630      233      134  Music
# ...
