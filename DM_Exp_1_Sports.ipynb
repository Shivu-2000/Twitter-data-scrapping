# %% [markdown]
# # Sports Tweet

# %%
#pip install snscrape 
#Sports

# %%
import pandas as pd
import snscrape.modules.twitter as sn

# %%
em=sn.TwitterUserScraper("FIFAcom")

# %%
li=[]
for i,tweet in enumerate(em.get_items()):
    if i>100:
        break
    li.append([tweet.rawContent,tweet.date,tweet.likeCount,tweet.retweetCount,tweet.replyCount,"Sports"])

# %%
df=pd.DataFrame(li,columns=['Tweet','Date','Like','Retweet','Comment','Output'])
df.to_csv('sports.csv')

# %%
file=pd.read_csv('sports.csv')
file
# Out:
#      Unnamed: 0                                              Tweet  \
# 0             0  Fans from every corner of the globe uniting in...
# 1             1  Football brings us joy, passion, peace and lov...
# 2             2  “Our aim is to create a more welcoming, inclus...
# 3             3  The finalists are in for each category for #Th...
# 4             4                                    @NormanMaroto 👏
# ..          ...                                                ...
# 96           96  "Football has lost one of its most beautiful a...
# 97           97  We are deeply saddened to hear of the passing ...
# 98           98  🇨🇻 Estádio Pelé\n🇨🇴 Bello Horizonte Rey Pelé\n...
# 99           99          @PLforIndia @BhupsGill_ARef Trailblazer 🙌
# 100         100          @SerieA @OfficialASRoma @Bolognafc1909 ❤️
#
#                           Date  Like  Retweet  Comment  Output
# 0    2023-02-12 10:46:15+00:00   682       43       19  Sports
# ...
